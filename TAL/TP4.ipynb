# %%
import spacy
import random
from pathlib import Path
from spacy.training.example import Example

# %% [markdown]
# # Training

# %% [markdown]
# data

# %%
# training data
#“few” “many” “enough” “some” “all” “half” “whole” and “numerous”

TRAIN_DATA = [
    ("he took half of the pizza", {
        'heads': [0, 1, 5, 5, 5, 5],
        'deps': ['-', '-', 'quantity', 'prep', 'det', '-']
    }),
    ("he deleted the whole document", {
        'heads': [0, 1, 4, 4, 4],
        'deps': ['-', '-', 'det', 'quantity', '-']
    }),
    ("only few people could pass the exam", {
        'heads': [0, 2, 2, 3, 4, 6, 6],
        'deps': ['-', 'quantity', '-', '-', '-', 'det', '-']
    }),
    ("I ate all London", {
        'heads': [0,1, 3, 3],
        'deps': ['-','-', 'quantity', '-']
    }),
    ("he ate many apples and a banana", {
        'heads': [0 , 1, 3, 3, 4, 5, 6],
        'deps': ['-','-', 'quantity', '-', '-','-', '-']
    }),   

    ("She found half of the treasure", {
        'heads': [0, 1, 5, 5, 5, 5],
        'deps': ['-', '-', 'quantity', 'prep', 'det', '-']
    }),    
    ("All the guests enjoyed the party", {
        'heads': [2, 2, 2, 3, 5, 5],
        'deps': ['quantity','det','-', '-', 'det', '-']
    }),
    ("I have some interesting books", {
        'heads': [0, 1, 4, 4, 4],
        'deps': ['-', '-', 'quantity', 'adj', '-']
    }),
    ("They completed half of the journey", {
        'heads': [0, 1, 5, 5, 5, 5],
        'deps': ['-', '-', 'quantity', 'prep', 'det', '-']
    }),
    ("The team won numerous awards", {
        'heads': [1, 1, 2, 4, 4],
        'deps': ['det', '-', '-', 'quantity', '-']
    }),
    ("He ate enough cake for three people", {
        'heads': [0, 1, 3, 3, 4, 6, 6],
        'deps': ['-', '-', 'quantity', '-', 'prep', 'quantity', '-']
    }),
    ("I read half of the novel", {
        'heads': [0, 1, 5, 5, 5, 5],
        'deps': ['-', '-', 'quantity', 'prep', 'det', '-']
    }),
    ("Few students attended the lecture", {
        'heads': [1, 1, 2, 4, 4],
        'deps': ['quantity', '-', '-', 'det', '-']
    }),
    ("They planted numerous flowers in the garden", {
        'heads': [0, 1, 3, 3, 4, 6, 6],
        'deps': ['-', '-', 'quantity', '-', '-', 'det','-']
    }),
    ("I have enough time to finish the project", {
        'heads': [0, 1, 3, 3, 4, 5, 7, 7],
        'deps': ['-', '-', 'quantity', '-', '-', '-', 'det','-']
    }),
    ("She bought some beautiful flowers", {
        'heads': [0, 1, 4, 4, 4],
        'deps': ['-', '-', 'quantity', 'adj', '-']
    }),
    ("We covered half of the distance", {
        'heads': [0, 1, 5, 5, 5, 5],
        'deps': ['-', '-', 'quantity', 'prep', 'det', '-']
    }),
    ("The restaurant serves delicious whole cakes", {
        'heads': [1, 1, 2, 3, 5, 5],
        'deps': ['det', '-', '-', '-', 'quantity', '-']
    }),
    ("They provided enough evidence for the case", {
        'heads': [0, 1, 3, 3, 5, 6, 6],
        'deps': ['-', '-', 'quantity', '-', '-', 'det', '-']
    }),    
    ("Half of the team participated in the competition", {
        'heads': [3, 3, 3, 3, 4, 5,7,7],
        'deps': ['quantity', 'prep', 'det', '-', '-', '-', 'det', '-']
    }),
    ("Numerous tourists visited the historical site", {
        'heads': [1, 1, 2, 5, 4, 5],
        'deps': ['quantity', '-', '-', 'det', '-', '-']
    }),    
    ("I bought enough groceries for the week", {
        'heads': [0, 1, 3, 3, 5, 6, 6],
        'deps': ['-', '-', 'quantity', '-', '-', 'det', '-']
    }),
    ("Whole families attended the festival", {
        'heads': [1, 1, 2, 4, 4],
        'deps': ['quantity', '-', '-', 'det', '-']
    }),
    ("Few students passed the challenging exam", {
        'heads': [1, 1, 2, 5, 4, 5],
        'deps': ['quantity', '-', '-', 'det', '-', '-']
    }),
    ("I spent half of my salary on the new phone", {
        'heads': [0, 1, 5, 5, 5, 5,6,9,8 ,9],
        'deps': ['-', '-', 'quantity', 'prep', 'det', '-', '-', 'det', '-', '-']
    }),    
    ("Some students completed the assignment", {
        'heads': [1, 1, 2, 3, 3],
        'deps': ['quantity', '-', '-', 'det', '-']
    }),
    ("Half of the employees attended the meeting", {
        'heads': [3, 3, 3,3, 4, 6,6],
        'deps': ['quantity', 'prep', 'det', '-', '-', 'det', '-']
    }),    
    ("I spent some time reading a good book", {
        'heads': [0, 1, 3, 3, 4, 5, 6,7],
        'deps': ['-', '-', 'quantity', '-', '-', '-', '-','-']
    }),
    ("Some people enjoyed the concert", {
        'heads': [1, 1, 2, 3, 3],
        'deps': ['quantity', '-', '-', 'det', '-']
    }),
    ("Half of the cake is missing", {
        'heads': [3, 3, 3, 3, 4,5],
        'deps': ['quantity', 'prep', 'det', '-', '-', '-']
    }),
    ("I bought some fresh vegetables", {
        'heads': [0, 1, 4, 4, 4],
        'deps': ['-', '-', 'quantity', 'adj', '-']
    }),    
    ("Some birds migrated south for the winter", {
        'heads': [1, 1, 2, 3, 4, 6,6],
        'deps': ['quantity', '-', '-', '-', '-', 'det', '-']
    }),
    ("Half of the students were absent", {
        'heads': [3, 3, 3, 3, 4,5],
        'deps': ['quantity', 'prep', 'det', '-', '-', '-']
    }),    
    ("I have some extra money for emergencies", {
        'heads': [0, 1, 4, 4, 4, 6, 6],
        'deps': ['-', '-', 'quantity', 'adj', '-', '-', '-']
    }),
    ("Half of the day is already gone", {
        'heads': [3, 3, 3, 3, 4, 5, 6],
        'deps': ['quantity', 'prep', 'det', '-', '-', '-', '-']
    }),
    ("i bought many books", {
        'heads': [0, 1, 3, 3],
        'deps': ['-', '-', 'quantity', '-']
    }),
    ("my friend sold all the apples", {
        'heads': [1, 1, 2, 5, 5, 5],
        'deps': ['prep', '-', '-', 'quantity','det', '-']
    }),
    ("I spent half of my salary on a new gadget", {
        'heads': [0, 1, 5, 5, 5, 5, 6, 7,8,9],
        'deps': ['-', '-', 'quantity', 'prep', 'det', '-', '-', '-', '-', '-']
    }),
]

# %% [markdown]
# prepare training and pipe

# %%
nlp = spacy.blank('en')

parser = nlp.add_pipe('parser')
for _, annotations in TRAIN_DATA:
        for dep in annotations.get('deps', []):
            parser.add_label(dep)
examples = []
for input_data, annot in TRAIN_DATA:
    doc = nlp.make_doc(input_data)
    example = Example.from_dict(doc, annot)
    examples.append(example)

# %% [markdown]
# Training

# %%
optimizer = nlp.begin_training()
for itn in range(20):
    random.shuffle(TRAIN_DATA)
    losses = {}
    for example in examples:
        print(nlp.update([example], sgd=optimizer,losses=losses))
# Out:
# {'parser': 2.650433123111725}
# {'parser': 4.716138137504458}
# {'parser': 8.667950209230185}
# {'parser': 11.43859362974763}
# {'parser': 12.963319791480899}
# {'parser': 15.267571298405528}
# {'parser': 17.45575533621013}
# {'parser': 19.420424185693264}
# {'parser': 23.27790898643434}
# {'parser': 26.39694037102163}
# {'parser': 30.203797552734613}
# {'parser': 34.06526509206742}
# {'parser': 36.9597997488454}
# {'parser': 39.19663393869996}
# {'parser': 41.454959670081735}
# {'parser': 44.5791142238304}
# {'parser': 48.45869387779385}
# {'parser': 50.549823412671685}
# {'parser': 52.98877412453294}
# {'parser': 55.214014639146626}
# {'parser': 56.11774185998365}
# {'parser': 58.410365304443985}
# {'parser': 60.11159485159442}
# {'parser': 60.9050846430473}
# {'parser': 62.985629776027054}
# {'parser': 65.88284826790914}
# {'parser': 67.80061238328926}
# {'parser': 69.78189103282057}
# {'parser': 72.61311941849999}
# {'parser': 76.43721660855226}
# {'parser': 78.62076290301047}
# {'parser': 80.53881930350326}
# {'parser': 81.66564978822134}
# {'parser': 83.9168985686265}
# {'parser': 86.71720715379342}
# {'parser': 88.17321974830702}
# {'parser': 90.6067004436627}
# {'parser': 96.38079788454343}
# {'parser': 2.6623937089461833}
# {'parser': 4.313154861563817}
# {'parser': 5.67603619187139}
# {'parser': 7.0468071738723665}
# {'parser': 8.139594177016988}
# {'parser': 10.103613933373708}
# {'parser': 11.731279825542515}
# {'parser': 14.12211950645542}
# {'parser': 15.688613362710385}
# {'parser': 16.561670844514083}
# {'parser': 18.102518388985118}
# {'parser': 19.119846440195033}
# {'parser': 19.821488880093966}
# {'parser': 21.130132835274708}
# {'parser': 22.231299301760828}
# {'parser': 24.25930826124977}
# {'parser': 24.65413794455867}
# {'parser': 26.329233527827228}
# {'parser': 28.335601426795392}
# {'parser': 29.12416612660968}
# {'parser': 30.71015460026979}
# {'parser': 32.42528721024905}
# {'parser': 32.89380485766219}
# {'parser': 33.728992866670296}
# {'parser': 34.68116847182931}
# {'parser': 36.85454518579006}
# {'parser': 37.45238547069577}
# {'parser': 40.162585500499446}
# {'parser': 42.50546669091584}
# {'parser': 43.20320886611391}
# {'parser': 45.522759810760746}
# {'parser': 46.652701992272725}
# {'parser': 46.986304947884875}
# {'parser': 50.23715361639363}
# {'parser': 50.79226034750347}
# {'parser': 51.99934892224398}
# {'parser': 53.011389920443136}
# {'parser': 54.01858193895775}
# {'parser': 0.49242327235697303}
# {'parser': 2.307155434291417}
# {'parser': 4.24983196159809}
# {'parser': 4.68911213581265}
# {'parser': 5.411606821449851}
# {'parser': 5.777173386368219}
# {'parser': 6.77103485940998}
# {'parser': 8.442882238889823}
# {'parser': 8.767203657935298}
# {'parser': 9.64218167982597}
# {'parser': 10.619690918692871}
# {'parser': 10.921906780617295}
# {'parser': 11.441305281272635}
# {'parser': 12.133715159525964}
# {'parser': 13.55062140015958}
# {'parser': 15.019707994483342}
# {'parser': 15.40576072493137}
# {'parser': 16.215925859396393}
# {'parser': 17.389150071674393}
# {'parser': 18.064977663511954}
# {'parser': 18.5246493047665}
# {'parser': 19.693596718031003}
# {'parser': 20.19575355745939}
# {'parser': 20.951403096647162}
# {'parser': 21.894090497705385}
# {'parser': 24.068366477161454}
# {'parser': 24.34617210679685}
# {'parser': 25.283722573130355}
# {'parser': 27.14149381569164}
# {'parser': 27.41973733224254}
# {'parser': 28.8276761286073}
# {'parser': 29.814566523744}
# {'parser': 30.287618981170716}
# {'parser': 32.05978359550799}
# {'parser': 32.618062384891395}
# {'parser': 32.961006143848515}
# {'parser': 33.50945828560838}
# {'parser': 34.66840575128827}
# {'parser': 0.4210043154103005}
# {'parser': 1.5659070629021699}
# {'parser': 2.3758648288542616}
# {'parser': 2.87434518621653}
# {'parser': 3.8949052909604376}
# {'parser': 4.228885818804862}
# {'parser': 5.493187397411422}
# {'parser': 6.540842981607543}
# {'parser': 6.987335746800974}
# {'parser': 7.311737069911062}
# {'parser': 7.850696490561417}
# {'parser': 8.084654071350277}
# {'parser': 8.421964250165853}
# {'parser': 8.973935977843745}
# {'parser': 10.04213909464666}
# {'parser': 10.732345138141845}
# {'parser': 11.216112534860697}
# {'parser': 11.852749560630059}
# {'parser': 13.127492598277884}
# {'parser': 13.520938377692316}
# {'parser': 13.933997205208724}
# {'parser': 14.853366119739025}
# {'parser': 15.2236365034667}
# {'parser': 15.741897218614675}
# {'parser': 16.693470252486875}
# {'parser': 18.281446202097428}
# {'parser': 18.784605627253008}
# {'parser': 19.690325936608424}
# {'parser': 21.554400038628103}
# {'parser': 21.937118107476195}
# {'parser': 23.86886765725232}
# {'parser': 24.64412652365284}
# {'parser': 24.913082744038302}
# {'parser': 27.141187311770466}
# {'parser': 27.732944437429786}
# {'parser': 28.200273446674533}
# {'parser': 30.890231967451758}
# {'parser': 31.507705009440627}
# {'parser': 0.2665314337796526}
# {'parser': 0.9149213974254464}
# {'parser': 1.832669100389864}
# {'parser': 2.034414241379982}
# {'parser': 2.7348177101408333}
# {'parser': 2.9868036095684545}
# {'parser': 4.318219894930246}
# {'parser': 6.468803901481618}
# {'parser': 6.794767592657564}
# {'parser': 7.425596260184628}
# {'parser': 8.25520935739954}
# {'parser': 8.608364135345706}
# {'parser': 8.986479933843608}
# {'parser': 9.645471990342497}
# {'parser': 10.489172753920595}
# {'parser': 11.04063047491832}
# {'parser': 11.382648383534333}
# {'parser': 11.890307263259995}
# {'parser': 12.373006841498512}
# {'parser': 12.91587220104092}
# {'parser': 13.514458809552778}
# {'parser': 14.268863731388834}
# {'parser': 14.672679539029533}
# {'parser': 15.219260795266438}
# {'parser': 16.343860175331763}
# {'parser': 17.68519103149822}
# {'parser': 17.913881586589504}
# {'parser': 19.072493796550496}
# {'parser': 20.27892412542301}
# {'parser': 20.586589733573618}
# {'parser': 20.93146379379087}
# {'parser': 21.441622258063568}
# {'parser': 21.722352240392645}
# {'parser': 22.536359344130013}
# {'parser': 22.896187701807406}
# {'parser': 23.29862316360651}
# {'parser': 24.18190543490341}
# {'parser': 25.439806416546187}
# {'parser': 0.27876281185763796}
# {'parser': 1.0847970631560873}
# {'parser': 1.7316104387978832}
# {'parser': 2.0599562707836627}
# {'parser': 3.2269540582698113}
# {'parser': 3.628815801941177}
# {'parser': 3.888866315782457}
# {'parser': 4.226823821329677}
# {'parser': 4.518956909185703}
# {'parser': 4.915549629434705}
# {'parser': 5.507792795993453}
# {'parser': 5.859502144508614}
# {'parser': 6.21497494369528}
# {'parser': 6.930343788718468}
# {'parser': 7.694985653438926}
# {'parser': 8.081480821591054}
# {'parser': 8.353140394257322}
# {'parser': 8.891540999097584}
# {'parser': 9.588804918800024}
# {'parser': 10.083523493652468}
# {'parser': 10.53602196005929}
# {'parser': 11.079251201958924}
# {'parser': 11.359797478523515}
# {'parser': 11.794191759063777}
# {'parser': 12.538615835771159}
# {'parser': 13.869597854333897}
# {'parser': 14.389426928430403}
# {'parser': 15.858697154264593}
# {'parser': 16.866084001837045}
# {'parser': 17.243327671117576}
# {'parser': 17.71758097771324}
# {'parser': 18.430861508735003}
# {'parser': 18.699783000682483}
# {'parser': 19.489763166294292}
# {'parser': 19.88181895031567}
# {'parser': 20.15008768343684}
# {'parser': 20.45571852788961}
# {'parser': 21.584087713233103}
# {'parser': 0.3981336155390638}
# {'parser': 2.4220455570038606}
# {'parser': 3.1631669730748024}
# {'parser': 3.6628392963332708}
# {'parser': 4.58597192909005}
# {'parser': 4.917115064340757}
# {'parser': 5.356824692107788}
# {'parser': 5.645026985567927}
# {'parser': 5.862008188078592}
# {'parser': 6.137473640633589}
# {'parser': 6.737017820361816}
# {'parser': 7.184625001579878}
# {'parser': 7.586126977798174}
# {'parser': 8.234241929075056}
# {'parser': 8.94762913571144}
# {'parser': 9.30818940549501}
# {'parser': 9.750899164693555}
# {'parser': 10.282035104738357}
# {'parser': 10.891808596720471}
# {'parser': 11.433383710282456}
# {'parser': 11.97813343341261}
# {'parser': 12.498946613258596}
# {'parser': 12.870298474151705}
# {'parser': 13.206330220887313}
# {'parser': 13.927209186373354}
# {'parser': 15.19025615280607}
# {'parser': 15.624827847360555}
# {'parser': 16.498397818230472}
# {'parser': 17.330226865673982}
# {'parser': 17.782650653143158}
# {'parser': 18.09028802484976}
# {'parser': 19.32233541667953}
# {'parser': 19.639252679861123}
# {'parser': 20.440149551019655}
# {'parser': 20.787242975879874}
# {'parser': 21.07445796985068}
# {'parser': 21.6193232585629}
# {'parser': 22.70642517069662}
# {'parser': 0.28539290077702506}
# {'parser': 2.321627108650044}
# {'parser': 3.0480232402754}
# {'parser': 3.3219564985124794}
# {'parser': 4.080445573910101}
# {'parser': 4.35315814033579}
# {'parser': 4.714268850449379}
# {'parser': 5.182129902207063}
# {'parser': 5.581240082189466}
# {'parser': 5.961766423082416}
# {'parser': 6.430004101288415}
# {'parser': 6.749340344107581}
# {'parser': 7.0548577640328265}
# {'parser': 7.552724988355171}
# {'parser': 8.316513560072458}
# {'parser': 8.70690122532797}
# {'parser': 9.053429906992404}
# {'parser': 9.564738413650161}
# {'parser': 9.961330252204712}
# {'parser': 10.433008107038546}
# {'parser': 10.840988626956696}
# {'parser': 11.273616126004471}
# {'parser': 11.662072304911904}
# {'parser': 12.174987017186437}
# {'parser': 13.161098028370777}
# {'parser': 13.725952287119286}
# {'parser': 14.056952377493497}
# {'parser': 14.931515671271814}
# {'parser': 15.506203564876165}
# {'parser': 15.769420940076603}
# {'parser': 16.144053398405358}
# {'parser': 17.394631382502805}
# {'parser': 17.70974398796276}
# {'parser': 18.883524324147146}
# {'parser': 19.688158779628964}
# {'parser': 20.024207809029633}
# {'parser': 20.273895285509834}
# {'parser': 21.451347653744023}
# {'parser': 0.3851927330221164}
# {'parser': 1.0825788832321512}
# {'parser': 1.6101825878541827}
# {'parser': 1.9941902605913886}
# {'parser': 2.6745549212485042}
# {'parser': 2.9607391606618974}
# {'parser': 3.282646432035946}
# {'parser': 3.699007581960627}
# {'parser': 4.008004797793033}
# {'parser': 4.409491831759592}
# {'parser': 5.07389955427548}
# {'parser': 5.454533907871669}
# {'parser': 5.8425154409356175}
# {'parser': 6.529490743268423}
# {'parser': 7.277741842219916}
# {'parser': 7.622794178483304}
# {'parser': 7.916852028473064}
# {'parser': 8.44155089443601}
# {'parser': 9.189376972207134}
# {'parser': 9.780798156369766}
# {'parser': 10.511827218358219}
# {'parser': 11.209174879088614}
# {'parser': 11.601536075186145}
# {'parser': 12.122726793807644}
# {'parser': 12.777167133742509}
# {'parser': 13.771068724998738}
# {'parser': 14.134634202143861}
# {'parser': 14.925716587708129}
# {'parser': 15.222071415410056}
# {'parser': 15.533007238156895}
# {'parser': 15.958548430802441}
# {'parser': 16.9618835805648}
# {'parser': 17.28867401600717}
# {'parser': 17.90743737222764}
# {'parser': 18.441611383801124}
# {'parser': 18.792621310268334}
# {'parser': 19.166901064811448}
# {'parser': 20.15477720728917}
# {'parser': 0.27044919636184955}
# {'parser': 1.4035080129059094}
# {'parser': 2.0500391907314697}
# {'parser': 2.2485764027452695}
# {'parser': 2.863395566802683}
# {'parser': 3.2452781751947266}
# {'parser': 3.703139441943492}
# {'parser': 4.0752841054560704}
# {'parser': 4.4727112867208465}
# {'parser': 4.772706859019689}
# {'parser': 5.63563882150072}
# {'parser': 5.999726632404386}
# {'parser': 6.324397887890395}
# {'parser': 6.803627324039559}
# {'parser': 7.663329681816213}
# {'parser': 7.956001468381768}
# {'parser': 8.21924787019451}
# {'parser': 8.537806730355324}
# {'parser': 9.296766606860892}
# {'parser': 9.899059684531474}
# {'parser': 10.511551575707122}
# {'parser': 11.058909867647868}
# {'parser': 11.408733608736085}
# {'parser': 12.059317739448534}
# {'parser': 13.10759298454854}
# {'parser': 13.665426042288505}
# {'parser': 14.04281064828748}
# {'parser': 14.849490343026385}
# {'parser': 15.208052766210981}
# {'parser': 15.530659042247713}
# {'parser': 15.706007315474839}
# {'parser': 16.203969736206645}
# {'parser': 16.56572497885025}
# {'parser': 17.568881076896087}
# {'parser': 18.06012642229434}
# {'parser': 18.50214610155437}
# {'parser': 18.7794953645711}
# {'parser': 19.69655572724973}
# {'parser': 0.28505143489369983}
# {'parser': 0.6055208944503329}
# {'parser': 1.1890410074583677}
# {'parser': 1.4904161663177342}
# {'parser': 2.441525297219295}
# {'parser': 2.750787124715864}
# {'parser': 3.0549019959277595}
# {'parser': 3.4881810963326445}
# {'parser': 3.6732652757632818}
# {'parser': 3.9639094656295724}
# {'parser': 4.755515518081187}
# {'parser': 5.070385749667832}
# {'parser': 5.403875498657962}
# {'parser': 6.046652722942528}
# {'parser': 6.8454365729447}
# {'parser': 7.247399391264651}
# {'parser': 7.661796939877977}
# {'parser': 8.030301179826152}
# {'parser': 8.570208467263011}
# {'parser': 9.277703985924248}
# {'parser': 9.614014709454114}
# {'parser': 10.0157852068196}
# {'parser': 10.393930696323807}
# {'parser': 10.791882939810828}
# {'parser': 11.893918244061815}
# {'parser': 12.75835144826652}
# {'parser': 13.248012215782474}
# {'parser': 14.529812545235956}
# {'parser': 14.907586700082708}
# {'parser': 15.303222778609074}
# {'parser': 15.489512402748964}
# {'parser': 15.876741048815276}
# {'parser': 16.17071188225131}
# {'parser': 16.53127973124491}
# {'parser': 16.845441682179814}
# {'parser': 17.010589555124017}
# {'parser': 17.294645579389005}
# {'parser': 18.388409409960406}
# {'parser': 0.4283948078348213}
# {'parser': 0.9137142176948659}
# {'parser': 1.6460607833306389}
# {'parser': 2.0506139484498287}
# {'parser': 3.100407690062577}
# {'parser': 3.4319239584238352}
# {'parser': 3.6276482601663336}
# {'parser': 3.7961846550013556}
# {'parser': 3.9986117402516976}
# {'parser': 4.31573961819928}
# {'parser': 4.882842305659387}
# {'parser': 5.179779119601391}
# {'parser': 5.507208865206293}
# {'parser': 6.11650905765631}
# {'parser': 7.108893408119689}
# {'parser': 7.533819308840038}
# {'parser': 7.856497869802011}
# {'parser': 8.583252302408438}
# {'parser': 9.125872143976537}
# {'parser': 9.540488851083582}
# {'parser': 10.0340939149648}
# {'parser': 10.433413206867431}
# {'parser': 10.618012429128546}
# {'parser': 10.9464369858703}
# {'parser': 11.633971884110686}
# {'parser': 12.10483321661143}
# {'parser': 12.454492770769114}
# {'parser': 13.480340685753346}
# {'parser': 13.85267734532512}
# {'parser': 14.138482940530068}
# {'parser': 14.427533288397637}
# {'parser': 15.113956711844201}
# {'parser': 15.489442635593107}
# {'parser': 15.90058716063064}
# {'parser': 16.30416504790809}
# {'parser': 16.510584043928496}
# {'parser': 16.752055060410584}
# {'parser': 17.673922870506868}
# {'parser': 0.273416375449408}
# {'parser': 1.3405943499630095}
# {'parser': 2.229111502333607}
# {'parser': 2.7230427433105566}
# {'parser': 3.8326885876162584}
# {'parser': 4.238518731631268}
# {'parser': 4.48093314531052}
# {'parser': 4.840426893177382}
# {'parser': 5.094968397509587}
# {'parser': 5.264095845380536}
# {'parser': 5.8631544455460105}
# {'parser': 6.145634158333393}
# {'parser': 6.502823173517855}
# {'parser': 7.269973473688395}
# {'parser': 8.155170931861855}
# {'parser': 8.57408793037892}
# {'parser': 8.937184877775708}
# {'parser': 9.330261563374286}
# {'parser': 9.862842875197936}
# {'parser': 10.245129122718444}
# {'parser': 10.74934340347249}
# {'parser': 11.148085700166007}
# {'parser': 11.350727199585311}
# {'parser': 11.926855513666016}
# {'parser': 12.731806742439497}
# {'parser': 13.42987039063113}
# {'parser': 13.717673011985863}
# {'parser': 14.741478849328665}
# {'parser': 15.024666736112632}
# {'parser': 15.531019945042859}
# {'parser': 15.79650037754678}
# {'parser': 16.516410030205098}
# {'parser': 16.851612455624704}
# {'parser': 17.391685729405385}
# {'parser': 17.94093646407008}
# {'parser': 18.19966757638911}
# {'parser': 18.5283502304172}
# {'parser': 19.24857229076044}
# {'parser': 0.254781990032019}
# {'parser': 0.5849263315651109}
# {'parser': 1.1733815473053668}
# {'parser': 1.55392281151863}
# {'parser': 2.317033204151727}
# {'parser': 2.5850454952543203}
# {'parser': 2.8961139918246714}
# {'parser': 3.299623778372377}
# {'parser': 3.7690934595949805}
# {'parser': 4.21007281291922}
# {'parser': 4.761151559965761}
# {'parser': 5.084049018881166}
# {'parser': 5.383570932726929}
# {'parser': 5.8586236912164456}
# {'parser': 6.718686086398847}
# {'parser': 6.947176508320661}
# {'parser': 7.313926941198362}
# {'parser': 7.780467606161469}
# {'parser': 8.272107607768355}
# {'parser': 8.921057368882263}
# {'parser': 9.455809704205539}
# {'parser': 10.046999306591417}
# {'parser': 10.438696018218383}
# {'parser': 10.806156875041598}
# {'parser': 11.336756530908424}
# {'parser': 11.54301842251225}
# {'parser': 11.73926591181556}
# {'parser': 12.377826667582664}
# {'parser': 12.799948787098097}
# {'parser': 13.194034932507876}
# {'parser': 13.55571233986313}
# {'parser': 14.398657134854936}
# {'parser': 14.71555333913259}
# {'parser': 15.050144282807993}
# {'parser': 15.446735115127382}
# {'parser': 15.698620064070452}
# {'parser': 16.05923703875775}
# {'parser': 17.000543000618453}
# {'parser': 0.3287775914121295}
# {'parser': 0.7460355238068116}
# {'parser': 1.4507476962346302}
# {'parser': 1.7205426572023959}
# {'parser': 2.5868661648794564}
# {'parser': 2.9712756023273945}
# {'parser': 3.2422752482610733}
# {'parser': 3.6225145850897515}
# {'parser': 3.937934416206317}
# {'parser': 4.201196091742328}
# {'parser': 4.872643886037023}
# {'parser': 5.138871376504886}
# {'parser': 5.388710419262651}
# {'parser': 5.992280468336911}
# {'parser': 6.8662759270409035}
# {'parser': 7.084226012818604}
# {'parser': 7.274434773604993}
# {'parser': 7.960918411285131}
# {'parser': 8.597890936604012}
# {'parser': 9.234773349305385}
# {'parser': 9.980580796529228}
# {'parser': 10.654741127643709}
# {'parser': 11.03301749020234}
# {'parser': 11.298960603488835}
# {'parser': 12.067799773524744}
# {'parser': 12.39455077107279}
# {'parser': 12.652379216662268}
# {'parser': 13.37050874280041}
# {'parser': 13.65015841064619}
# {'parser': 13.949460712825166}
# {'parser': 14.345802351178056}
# {'parser': 15.225238457016907}
# {'parser': 15.678107658132143}
# {'parser': 16.267935718487717}
# {'parser': 16.875148569644466}
# {'parser': 17.176423499448475}
# {'parser': 17.53848973178972}
# {'parser': 18.393147607819245}
# {'parser': 0.23479441966796905}
# {'parser': 0.48824654986949456}
# {'parser': 1.0568067207953333}
# {'parser': 1.3298845511512678}
# {'parser': 2.3576569133821303}
# {'parser': 2.53126539966817}
# {'parser': 2.970111996845071}
# {'parser': 3.3744274514742063}
# {'parser': 3.8373838794566355}
# {'parser': 4.154537838587162}
# {'parser': 4.97548642171551}
# {'parser': 5.450739709212153}
# {'parser': 5.755972381599501}
# {'parser': 6.36188815167683}
# {'parser': 6.875613697459812}
# {'parser': 7.2384470779021886}
# {'parser': 7.596354768059844}
# {'parser': 8.005988513274678}
# {'parser': 8.425343294701694}
# {'parser': 8.819641750350616}
# {'parser': 9.530684289767358}
# {'parser': 9.779744073933163}
# {'parser': 9.990119623813017}
# {'parser': 10.590999591588105}
# {'parser': 11.78606085627992}
# {'parser': 12.227638905749398}
# {'parser': 12.551731657269428}
# {'parser': 13.745604104317358}
# {'parser': 14.173479067172998}
# {'parser': 14.400500908459055}
# {'parser': 14.620534501351397}
# {'parser': 15.14776946026914}
# {'parser': 15.425258345527618}
# {'parser': 15.767948695816832}
# {'parser': 16.081841289991697}
# {'parser': 16.406361016299172}
# {'parser': 16.925368641510985}
# {'parser': 17.88876088387416}
# {'parser': 0.3705973421532589}
# {'parser': 0.9998958873970626}
# {'parser': 1.765909270932416}
# {'parser': 2.128440338276601}
# {'parser': 2.553364572902803}
# {'parser': 2.840702526068016}
# {'parser': 3.102686712987497}
# {'parser': 3.4063338423846994}
# {'parser': 3.5689285641864994}
# {'parser': 3.8320063186932853}
# {'parser': 4.583267556579953}
# {'parser': 5.007032696851519}
# {'parser': 5.446643316232822}
# {'parser': 6.211264739190502}
# {'parser': 7.0954980808639245}
# {'parser': 7.487571990013856}
# {'parser': 7.753151398792666}
# {'parser': 8.128329634741187}
# {'parser': 8.545687827946974}
# {'parser': 8.946194958648963}
# {'parser': 9.372548507359365}
# {'parser': 9.696073528947606}
# {'parser': 9.976277163195503}
# {'parser': 10.46967583654214}
# {'parser': 11.352569026457356}
# {'parser': 11.7412621975291}
# {'parser': 12.19623467201673}
# {'parser': 13.520120168454367}
# {'parser': 13.91378253854566}
# {'parser': 14.326665782722984}
# {'parser': 14.60772145316932}
# {'parser': 15.106127200506767}
# {'parser': 15.41992013436224}
# {'parser': 15.81592861378713}
# {'parser': 16.08548604694163}
# {'parser': 16.371124389211527}
# {'parser': 16.71315975160332}
# {'parser': 17.744719056180323}
# {'parser': 0.41296244266712795}
# {'parser': 0.8295532461945774}
# {'parser': 1.40496666379754}
# {'parser': 1.7703498543406944}
# {'parser': 2.4479893725207673}
# {'parser': 2.8272761901511565}
# {'parser': 3.1507337667590103}
# {'parser': 3.519790447518032}
# {'parser': 3.9079994570707552}
# {'parser': 4.149520268794018}
# {'parser': 4.704638556214562}
# {'parser': 4.928443493140524}
# {'parser': 5.103853164621995}
# {'parser': 5.589228065550213}
# {'parser': 6.504983510080585}
# {'parser': 6.848926465023724}
# {'parser': 7.137828311059552}
# {'parser': 7.607163117730325}
# {'parser': 8.209122310152864}
# {'parser': 8.715972895718783}
# {'parser': 9.501735987166414}
# {'parser': 10.079081908982838}
# {'parser': 10.351455424447977}
# {'parser': 10.902892325337929}
# {'parser': 11.426072072815444}
# {'parser': 11.739881018096973}
# {'parser': 12.027279701484078}
# {'parser': 13.238606353444656}
# {'parser': 13.560901920200921}
# {'parser': 13.852474435116246}
# {'parser': 14.277304319444921}
# {'parser': 15.216491911017787}
# {'parser': 15.644571525190798}
# {'parser': 16.27002174809615}
# {'parser': 16.788664616147543}
# {'parser': 17.066968559199527}
# {'parser': 17.429508416929178}
# {'parser': 18.30594901833043}
# {'parser': 0.24756753502016005}
# {'parser': 0.7811092449771985}
# {'parser': 1.3233141067862324}
# {'parser': 1.5853353934054581}
# {'parser': 2.518914040999971}
# {'parser': 2.7027837848898786}
# {'parser': 3.0630557242879917}
# {'parser': 3.3518174810185837}
# {'parser': 3.695216009055477}
# {'parser': 4.127675324585178}
# {'parser': 5.012688911969728}
# {'parser': 5.458562184792641}
# {'parser': 5.8619420709149965}
# {'parser': 6.624509146987045}
# {'parser': 7.348480652285752}
# {'parser': 7.72645307724226}
# {'parser': 8.157277876023393}
# {'parser': 8.523729395268344}
# {'parser': 8.92918522608088}
# {'parser': 9.378429269047222}
# {'parser': 9.794923617205072}
# {'parser': 10.279861143470182}
# {'parser': 10.586884855717505}
# {'parser': 11.083419792007273}
# {'parser': 11.840154902345363}
# {'parser': 12.086794469202442}
# {'parser': 12.367903636669878}
# {'parser': 13.340251869505616}
# {'parser': 13.640001661067664}
# {'parser': 13.95763045323602}
# {'parser': 14.273587770647586}
# {'parser': 15.13219903891026}
# {'parser': 15.43355359980862}
# {'parser': 16.02438520023448}
# {'parser': 16.6858267679161}
# {'parser': 17.084079378100945}
# {'parser': 17.468928583797716}
# {'parser': 18.64729496091251}
# {'parser': 0.2670037872535286}
# {'parser': 0.4550947144148031}
# {'parser': 0.823918465784017}
# {'parser': 1.0053122966539965}
# {'parser': 1.5095551571837047}
# {'parser': 1.6799825754808562}
# {'parser': 2.0245681510150266}
# {'parser': 2.2820438654374873}
# {'parser': 2.664811978142522}
# {'parser': 3.004891907637097}
# {'parser': 3.869791239145169}
# {'parser': 4.282949717594873}
# {'parser': 4.752488226805663}
# {'parser': 5.546452207475104}
# {'parser': 6.540339653644595}
# {'parser': 6.926917207755111}
# {'parser': 7.112002390070544}
# {'parser': 7.632605642208657}
# {'parser': 7.909252007038723}
# {'parser': 8.291306848835028}
# {'parser': 8.649069262172823}
# {'parser': 8.936190071529428}
# {'parser': 9.235091976840156}
# {'parser': 9.642416578461779}
# {'parser': 10.531989314680965}
# {'parser': 10.906021971962621}
# {'parser': 11.329038557340766}
# {'parser': 12.36577172141422}
# {'parser': 12.68498934346367}
# {'parser': 13.056903522794022}
# {'parser': 13.332819037848349}
# {'parser': 14.030690502209007}
# {'parser': 14.30833781179489}
# {'parser': 14.95124071660802}
# {'parser': 15.347289142765579}
# {'parser': 15.650883581469346}
# {'parser': 16.021057069296806}
# {'parser': 17.055371337406154}

# %% [markdown]
# save parser

# %%
nlp.to_disk("depentency_parser")

# %% [markdown]
# load parser

# %%
nlp = spacy.load("depentency_parser")

# %% [markdown]
# Example

# %%
TEST_DATA = [
    
    ("She bought some delicious cookies at the bakery.", {
        'heads': [1, 1, 2, 3, 3, 6, 8],
        'deps': ['nsubj', 'ROOT', 'quantity', 'amod', 'dobj', 'prep', 'det']
    }),
    ("I spent half of my salary on a new gadget.", {
        'heads': [0, 1, 2, 3, 5, 7, 7, 7],
        'deps': ['-', '-', '-', 'quantity', 'prep', 'poss', 'det', 'dobj']
    }),
    ("All the guests enjoyed the party", {
        'heads': [2, 2, 2, 3, 5, 5],
        'deps': ['quantity','det','-', '-', 'det', '-']
    }),
    ("The team won numerous awards", {
        'heads': [1, 1, 2, 4, 4],
        'deps': ['det', '-', '-', 'quantity', '-']
    }),    
    ("The restaurant serves delicious whole cakes", {
        'heads': [1, 1, 2, 3, 5, 5],
        'deps': ['det', '-', '-', '-', 'quantity', '-']
    }),
    ("They provided enough evidence for the case", {
        'heads': [0, 1, 3, 3, 5, 6, 6],
        'deps': ['-', '-', 'quantity', '-', '-', 'det', '-']
    }),    
    ("Half of the team participated in the competition", {
        'heads': [3, 3, 3, 3, 4, 5,7,7],
        'deps': ['quantity', 'prep', 'det', '-', '-', '-', 'det', '-']
    }),
    ("Numerous tourists visited the historical site", {
        'heads': [1, 1, 2, 5, 4, 5],
        'deps': ['quantity', '-', '-', 'det', '-', '-']
    }),    
    ("I bought enough groceries for the week", {
        'heads': [0, 1, 3, 3, 5, 6, 6],
        'deps': ['-', '-', 'quantity', '-', '-', 'det', '-']
    }),
    ("Whole families attended the festival", {
        'heads': [1, 1, 2, 4, 4],
        'deps': ['quantity', '-', '-', 'det', '-']
    }),
]

# %%
for test_text in TEST_DATA:
    doc = nlp(test_text[0])
    spacy.displacy.render(doc, style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="9e6e77f7e321479ea6ec79b25fa77827-0" class="displacy" width="1450" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Half</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">team</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">participated</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">competition</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275"></tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9e6e77f7e321479ea6ec79b25fa77827-0-0" stroke-width="2px" d="M70,264.5 C70,2.0 575.0,2.0 575.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9e6e77f7e321479ea6ec79b25fa77827-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">quantity</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,266.5 L62,254.5 78,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9e6e77f7e321479ea6ec79b25fa77827-0-1" stroke-width="2px" d="M245,264.5 C245,89.5 570.0,89.5 570.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9e6e77f7e321479ea6ec79b25fa77827-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,266.5 L237,254.5 253,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9e6e77f7e321479ea6ec79b25fa77827-0-2" stroke-width="2px" d="M420,264.5 C420,177.0 565.0,177.0 565.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9e6e77f7e321479ea6ec79b25fa77827-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,266.5 L412,254.5 428,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9e6e77f7e321479ea6ec79b25fa77827-0-3" stroke-width="2px" d="M1120,264.5 C1120,177.0 1265.0,177.0 1265.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9e6e77f7e321479ea6ec79b25fa77827-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1120,266.5 L1112,254.5 1128,254.5" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="3038396d3f534f4f8c8a799ecada7169-0" class="displacy" width="1100" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">All</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">guests</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">enjoyed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">party</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925"></tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3038396d3f534f4f8c8a799ecada7169-0-0" stroke-width="2px" d="M70,177.0 C70,2.0 400.0,2.0 400.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3038396d3f534f4f8c8a799ecada7169-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">quantity</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3038396d3f534f4f8c8a799ecada7169-0-1" stroke-width="2px" d="M245,177.0 C245,89.5 395.0,89.5 395.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3038396d3f534f4f8c8a799ecada7169-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,179.0 L237,167.0 253,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3038396d3f534f4f8c8a799ecada7169-0-2" stroke-width="2px" d="M770,177.0 C770,89.5 920.0,89.5 920.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3038396d3f534f4f8c8a799ecada7169-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,179.0 L762,167.0 778,167.0" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="ab017e9f55794bc49f7d47883b6882fb-0" class="displacy" width="1800" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">spent</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">half</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">my</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">salary</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">new</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">gadget.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625"></tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ab017e9f55794bc49f7d47883b6882fb-0-0" stroke-width="2px" d="M420,264.5 C420,2.0 925.0,2.0 925.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ab017e9f55794bc49f7d47883b6882fb-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">quantity</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,266.5 L412,254.5 428,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ab017e9f55794bc49f7d47883b6882fb-0-1" stroke-width="2px" d="M595,264.5 C595,89.5 920.0,89.5 920.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ab017e9f55794bc49f7d47883b6882fb-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,266.5 L587,254.5 603,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ab017e9f55794bc49f7d47883b6882fb-0-2" stroke-width="2px" d="M770,264.5 C770,177.0 915.0,177.0 915.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ab017e9f55794bc49f7d47883b6882fb-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,266.5 L762,254.5 778,254.5" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="47d8f70f31c24b7e84476a93e1432849-0" class="displacy" width="925" height="224.5" direction="ltr" style="max-width: none; height: 224.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Whole</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">families</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">attended</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">festival</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750"></tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-47d8f70f31c24b7e84476a93e1432849-0-0" stroke-width="2px" d="M70,89.5 C70,2.0 225.0,2.0 225.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-47d8f70f31c24b7e84476a93e1432849-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">quantity</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,91.5 L62,79.5 78,79.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-47d8f70f31c24b7e84476a93e1432849-0-1" stroke-width="2px" d="M595,89.5 C595,2.0 750.0,2.0 750.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-47d8f70f31c24b7e84476a93e1432849-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,91.5 L587,79.5 603,79.5" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="cdd47684f1f646ca83af7cff941518f8-0" class="displacy" width="1450" height="224.5" direction="ltr" style="max-width: none; height: 224.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">She</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">bought</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">some</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">delicious</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">cookies</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">bakery.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275"></tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cdd47684f1f646ca83af7cff941518f8-0-0" stroke-width="2px" d="M420,89.5 C420,2.0 575.0,2.0 575.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cdd47684f1f646ca83af7cff941518f8-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">quantity</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,91.5 L412,79.5 428,79.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cdd47684f1f646ca83af7cff941518f8-0-1" stroke-width="2px" d="M1120,89.5 C1120,2.0 1275.0,2.0 1275.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cdd47684f1f646ca83af7cff941518f8-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1120,91.5 L1112,79.5 1128,79.5" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="47600dea50c2489abd92e50050c82597-0" class="displacy" width="925" height="224.5" direction="ltr" style="max-width: none; height: 224.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">team</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">won</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">numerous</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">awards</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750"></tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-47600dea50c2489abd92e50050c82597-0-0" stroke-width="2px" d="M70,89.5 C70,2.0 225.0,2.0 225.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-47600dea50c2489abd92e50050c82597-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,91.5 L62,79.5 78,79.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-47600dea50c2489abd92e50050c82597-0-1" stroke-width="2px" d="M595,89.5 C595,2.0 750.0,2.0 750.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-47600dea50c2489abd92e50050c82597-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">quantity</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,91.5 L587,79.5 603,79.5" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="a3ab751342014c8c81737ab09d23d1e8-0" class="displacy" width="1100" height="224.5" direction="ltr" style="max-width: none; height: 224.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Numerous</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">tourists</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">visited</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">historical</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">site</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925"></tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a3ab751342014c8c81737ab09d23d1e8-0-0" stroke-width="2px" d="M70,89.5 C70,2.0 225.0,2.0 225.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a3ab751342014c8c81737ab09d23d1e8-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">quantity</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,91.5 L62,79.5 78,79.5" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="e90a31132667498e84af8f068a8613f2-0" class="displacy" width="1275" height="224.5" direction="ltr" style="max-width: none; height: 224.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">bought</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">enough</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">groceries</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">week</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100"></tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e90a31132667498e84af8f068a8613f2-0-0" stroke-width="2px" d="M420,89.5 C420,2.0 575.0,2.0 575.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e90a31132667498e84af8f068a8613f2-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">quantity</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,91.5 L412,79.5 428,79.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e90a31132667498e84af8f068a8613f2-0-1" stroke-width="2px" d="M770,89.5 C770,2.0 925.0,2.0 925.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e90a31132667498e84af8f068a8613f2-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">-</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,91.5 L762,79.5 778,79.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e90a31132667498e84af8f068a8613f2-0-2" stroke-width="2px" d="M945,89.5 C945,2.0 1100.0,2.0 1100.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e90a31132667498e84af8f068a8613f2-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,91.5 L937,79.5 953,79.5" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="a612638a76e44d49834587e59d376cb2-0" class="displacy" width="1275" height="224.5" direction="ltr" style="max-width: none; height: 224.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">They</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">provided</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">enough</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">evidence</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">case</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100"></tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a612638a76e44d49834587e59d376cb2-0-0" stroke-width="2px" d="M420,89.5 C420,2.0 575.0,2.0 575.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a612638a76e44d49834587e59d376cb2-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">quantity</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,91.5 L412,79.5 428,79.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a612638a76e44d49834587e59d376cb2-0-1" stroke-width="2px" d="M770,89.5 C770,2.0 925.0,2.0 925.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a612638a76e44d49834587e59d376cb2-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">-</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,91.5 L762,79.5 778,79.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a612638a76e44d49834587e59d376cb2-0-2" stroke-width="2px" d="M945,89.5 C945,2.0 1100.0,2.0 1100.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a612638a76e44d49834587e59d376cb2-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,91.5 L937,79.5 953,79.5" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="a55bccc85e024bc7bd250b14cbecafa6-0" class="displacy" width="1100" height="224.5" direction="ltr" style="max-width: none; height: 224.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">restaurant</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">serves</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">delicious</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">whole</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">cakes</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925"></tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a55bccc85e024bc7bd250b14cbecafa6-0-0" stroke-width="2px" d="M70,89.5 C70,2.0 225.0,2.0 225.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a55bccc85e024bc7bd250b14cbecafa6-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,91.5 L62,79.5 78,79.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a55bccc85e024bc7bd250b14cbecafa6-0-1" stroke-width="2px" d="M770,89.5 C770,2.0 925.0,2.0 925.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a55bccc85e024bc7bd250b14cbecafa6-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">quantity</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,91.5 L762,79.5 778,79.5" fill="currentColor"/>
# </g>
# </svg></span>
